# %% [markdown]
# <a href="https://colab.research.google.com/github/slave8/aistudy/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 첫번째 파이썬 프로그램

# %%
print("Hello Python")
# Out:
# Hello Python
